# %% [markdown]
# # Tutorial: ACCorDIoN test data

# %% [markdown]
# ## Load Libraries

# %%
from accordion import pdac
from accordion import utils as autils
from accordion.Accordion import Accordion 
import numpy as np
import numpy.linalg as lg
import networkx as nx
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import ot
from scipy import stats
from scipy import interpolate
from scipy.spatial.distance import pdist,squareform
import scipy.linalg as slg
import sklearn.metrics as measu
from sklearn import covariance
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.manifold import MDS
import logging as log
from accordion import utils as ault
from accordion import distances as acdist
from tqdm import tqdm

# %% [markdown]
# #### 1. Loading data and metadata

# %%
data = pdac.load_peng2019()
pdata_metadata = pdac.load_peng2019_metadata()
pdata_metadata['label1'] = ['Normal Pancreas' if i.find('normal')>= 0 else 'PDAC' for i in pdata_metadata.accLabel]

# %% [markdown]
# #### 2. This are tables made by CrossTalkeR/Liana therefore we need to filter it to keep only the single(per sample) networks

# %%
data = {i:data[i] for i in data.keys()  if i.find("_x_") < 0 }

# %% [markdown]
# #### 3. Now with the tables from CrossTalkeR/Liana we build the Accordion Object

# %%
AaccPDAC = Accordion(tbls=data,weight='lr_means')

# %%
AaccPDAC.make_pca()

# %%
for i in AaccPDAC.p.columns:
    AaccPDAC.p[i] = AaccPDAC.p[i]/AaccPDAC.p[i].sum()

# %%
AaccPDAC.compute_cost_all()
# Out:
# CTD
# ('distance', 'correlation')
# glasso
# option not found
# /home/james/.local/lib/python3.10/site-packages/accordion/distances.py:13: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   A = nx.adjacency_matrix(G,weight=weight).todense()

# %%
AaccPDAC.compute_cost(mode='distancePCA',metric='euclidean')

# %%
glasso = covariance.GraphicalLassoCV(cv=5,mode='cd',max_iter=100)
glasso.fit(AaccPDAC.p.T.to_numpy())
partial_correlations = glasso.precision_.copy()
d = 1 / np.sqrt(np.diag(partial_correlations))
partial_correlations *= d
partial_correlations *= d[:, np.newaxis]
non_zero = np.triu(1-partial_correlations, k=0)
non_zero = (non_zero +non_zero.T)	
#self.Cs['glasso'] = np.abs(non_zero)
# Out:
# /home/james/.local/lib/python3.10/site-packages/numpy/core/_methods.py:173: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)

# %%
sns.clustermap(non_zero,method='complete')

# %%
AaccPDAC.Cs['glasso']=non_zero

# %%
AaccPDAC.compute_wassestein(cost='CTD')
AaccPDAC.compute_wassestein(cost='correlation')
AaccPDAC.compute_wassestein(cost='glasso')
#AaccPDAC.compute_wassestein(cost='CTD',algorithm='sinkhorn',reg=0.1)
#AaccPDAC.compute_wassestein(cost='CTD',algorithm='sinkhorn',reg=0.001)
# Out:
# ...
# 100%|███████████████████████████████████████████| 35/35 [00:00<00:00, 82.86it/s]

# %%
AaccPDAC.wdist.keys()
# Out:
# dict_keys(['PCA_euclidean', 'CTD', 'correlation', 'glasso'])

# %%
AaccPDAC.eval_all(y=pdata_metadata.loc[AaccPDAC.p.columns,'label1'])
# Out:
# {'PCA_euclidean': {'ARS': 0.04101483251431405,
#   'Silhouette_Wass': -1.2112141824131978e-16,
#   'Silhouette': -1.2112141824131978e-16},
#  'CTD': {'ARS': 0.8847766158612991,
#   'Silhouette_Wass': 0.4195478762040835,
#   'Silhouette': 0.4195478762040835},
#  'correlation': {'ARS': 1.0,
#   'Silhouette_Wass': 0.574623266042782,
#   'Silhouette': 0.574623266042782},
#  'glasso': {'ARS': 0.8847766158612991,
#   'Silhouette_Wass': 0.41603505059813983,
#   'Silhouette': 0.41603505059813983}}

# %%
_,ax1 = plt.subplots(1,4,figsize=(15,5))
ax1[0].imshow(AaccPDAC.Cs['correlation'],cmap='RdYlBu')
ax1[0].set_title('correlation')
ax1[1].imshow(AaccPDAC.Cs['glasso'],cmap='RdYlBu')
ax1[1].set_title('glasso_cv_10')
ax1[2].imshow(AaccPDAC.Cs['CTD'],cmap='RdYlBu')
ax1[2].set_title('CTD')
ax1[3].imshow(AaccPDAC.Cs['PCA'],cmap='RdYlBu')
ax1[3].set_title('distancePCA')
# Out:
# Text(0.5, 1.0, 'distancePCA')

# %%
AaccPDAC.Cs['glasso']
# Out:
# array([[ 0.00000000e+00,  1.00000000e+00,  1.00000000e+00, ...,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#        [ 1.00000000e+00,  0.00000000e+00,  1.00000000e+00, ...,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#        [ 1.00000000e+00,  1.00000000e+00,  0.00000000e+00, ...,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#        ...,
#        [ 1.00000000e+00,  1.00000000e+00,  1.00000000e+00, ...,
#          0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#        [ 1.00000000e+00,  1.00000000e+00,  1.00000000e+00, ...,
#          1.00000000e+00, -4.44089210e-16,  1.00000000e+00],
#        [ 1.00000000e+00,  1.00000000e+00,  1.00000000e+00, ...,
#          1.00000000e+00,  1.00000000e+00,  2.22044605e-16]])

# %%
AaccPDAC.Cs['CTD']
# Out:
# array([[0.    , 0.3605, 0.3483, ..., 0.3481, 0.3481, 0.3425],
#        [0.3605, 0.    , 0.366 , ..., 0.366 , 0.366 , 0.3606],
#        [0.3483, 0.366 , 0.    , ..., 0.3536, 0.3536, 0.3481],
#        ...,
#        [0.3481, 0.366 , 0.3536, ..., 0.    , 0.3536, 0.3483],
#        [0.3481, 0.366 , 0.3536, ..., 0.3536, 0.    , 0.3482],
#        [0.3425, 0.3606, 0.3481, ..., 0.3483, 0.3482, 0.    ]])

# %%
AaccPDAC.Cs['correlation']
# Out:
# array([[0.        , 1.03505957, 0.10350813, ..., 1.16148706, 1.55154487,
#         1.24351323],
#        [1.03505957, 0.        , 1.13174015, ..., 1.46678805, 1.17570554,
#         1.39069115],
#        [0.10350813, 1.13174015, 0.        , ..., 1.09378976, 1.38178461,
#         1.20584361],
#        ...,
#        [1.16148706, 1.46678805, 1.09378976, ..., 0.        , 0.58580305,
#         0.08362415],
#        [1.55154487, 1.17570554, 1.38178461, ..., 0.58580305, 0.        ,
#         0.52518739],
#        [1.24351323, 1.39069115, 1.20584361, ..., 0.08362415, 0.52518739,
#         0.        ]])
