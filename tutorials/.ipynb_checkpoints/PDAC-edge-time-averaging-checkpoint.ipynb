# %% [markdown]
# # Tutorial: ACCorDIoN test data

# %% [markdown]
# James S. Nagai
#
# 02.05.2023
#
# *Note: Before using ACCorDIoN make sure that you have the CrossTalkeR installed in your local R enviroment*
#
# CrossTalkeR object are read using the function
# ```{python}
# parse_CrossTalkeR("file_path/LR.Rds")
# ```

# %% [markdown]
# ## Load Libraries

# %%
from accordion import pdac,utils,distances
from accordion.Accordion import Accordion 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pydiffmap as dm
import pandas as pd
import networkx as nx
from skimpy import skim
from sklearn import covariance
import random
random.seed(42)

# %% [markdown]
# #### 1. Loading data and metadata

# %%
data = pdac.load_peng2019()
pdata_metadata = pdac.load_peng2019_metadata()
pdata_metadata['label1'] = ['Normal Pancreas' if i.find('normal')>= 0 else 'PDAC' for i in pdata_metadata.accLabel]

# %% [markdown]
# #### 2. This are tables made by CrossTalkeR/Liana therefore we need to filter it to keep only the single(per sample) networks

# %%
data = {i:data[i] for i in data.keys()  if i.find("_x_") < 0 }

# %% [markdown]
# #### 3. Now with the tables from CrossTalkeR/Liana we build the Accordion Object

# %%
AaccPDAC = Accordion(tbls=data,weight='lr_means')

# %% [markdown]
# #### 4. Computing a PCA using the edge distribuition per sample

# %%
AaccPDAC.make_pca()

# %%
sns.scatterplot(x=0,y=1,data=AaccPDAC.Cs['PCA'],
                hue=pdata_metadata.loc[AaccPDAC.Cs['PCA'].index,'accLabel'])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("PC1")
plt.ylabel("PC2")
# Out:
# Text(0, 0.5, 'PC2')

# %% [markdown]
# #### 5. Normalizing the data $\mathcal{P}$

# %%
for i in AaccPDAC.p.columns:
    AaccPDAC.p[i] = AaccPDAC.p[i]/AaccPDAC.p[i].sum()

# %%
   AaccPDAC.p
# Out:
#                                        T23       T17        T9       T11  \
# Acinar cell_Ductal cell type 2         0.0  0.000000  0.000000  0.000000
# Acinar cell_Endothelial cell           0.0  0.000000  0.000000  0.000000
# Acinar cell_Stellate cell              0.0  0.000000  0.000000  0.000000
# Acinar cell_Fibroblast cell            0.0  0.000000  0.000000  0.000000
# Acinar cell_Ductal cell type 1         0.0  0.000000  0.000000  0.000000
# ...                                    ...       ...       ...       ...
# Ductal cell type 1_Macrophage cell     0.0  0.011249  0.015467  0.017145
# Ductal cell type 1_Stellate cell       0.0  0.011925  0.014446  0.014427
# Ductal cell type 1_T cell              0.0  0.003535  0.013554  0.012093
# Ductal cell type 1_Fibroblast cell     0.0  0.011731  0.014655  0.012782
# Ductal cell type 1_Ductal cell type 1  0.0  0.010557  0.013004  0.019422
#
#                                              N2       T13        N9  T10  \
# Acinar cell_Ductal cell type 2         0.000000  0.008447  0.000000  0.0
# Acinar cell_Endothelial cell           0.011089  0.010436  0.011608  0.0
# Acinar cell_Stellate cell              0.004110  0.005987  0.004072  0.0
# Acinar cell_Fibroblast cell            0.010045  0.007614  0.009278  0.0
# Acinar cell_Ductal cell type 1         0.006948  0.008619  0.007467  0.0
# ...                                         ...       ...       ...  ...
# Ductal cell type 1_Macrophage cell     0.020214  0.014491  0.017043  0.0
# Ductal cell type 1_Stellate cell       0.013871  0.010634  0.019688  0.0
# Ductal cell type 1_T cell              0.000000  0.010510  0.000000  0.0
# Ductal cell type 1_Fibroblast cell     0.028380  0.012696  0.020468  0.0
# Ductal cell type 1_Ductal cell type 1  0.032054  0.018314  0.026550  0.0
#
#                                             T19        N7  ...        N8  \
# Acinar cell_Ductal cell type 2         0.006195  0.000000  ...  0.000000
# Acinar cell_Endothelial cell           0.007486  0.010267  ...  0.005127
# Acinar cell_Stellate cell              0.003550  0.004558  ...  0.001122
# Acinar cell_Fibroblast cell            0.003793  0.013454  ...  0.004725
# Acinar cell_Ductal cell type 1         0.004435  0.003258  ...  0.005826
# ...                                         ...       ...  ...       ...
# Ductal cell type 1_Macrophage cell     0.014603  0.010026  ...  0.019473
# Ductal cell type 1_Stellate cell       0.010592  0.010131  ...  0.012316
# Ductal cell type 1_T cell              0.012061  0.011444  ...  0.014198
# Ductal cell type 1_Fibroblast cell     0.011878  0.024998  ...  0.021260
# Ductal cell type 1_Ductal cell type 1  0.016094  0.020040  ...  0.023644
#
#                                             T16  T22       T15  T18   T3  \
# Acinar cell_Ductal cell type 2         0.008272  0.0  0.003933  0.0  0.0
# Acinar cell_Endothelial cell           0.007232  0.0  0.004849  0.0  0.0
# Acinar cell_Stellate cell              0.003794  0.0  0.002087  0.0  0.0
# Acinar cell_Fibroblast cell            0.004292  0.0  0.002574  0.0  0.0
# Acinar cell_Ductal cell type 1         0.006254  0.0  0.003194  0.0  0.0
# ...                                         ...  ...       ...  ...  ...
# Ductal cell type 1_Macrophage cell     0.012393  0.0  0.011222  0.0  0.0
# Ductal cell type 1_Stellate cell       0.010667  0.0  0.011228  0.0  0.0
# Ductal cell type 1_T cell              0.007630  0.0  0.007163  0.0  0.0
# Ductal cell type 1_Fibroblast cell     0.012672  0.0  0.015179  0.0  0.0
# Ductal cell type 1_Ductal cell type 1  0.015912  0.0  0.015996  0.0  0.0
#
#                                              T2       T24       T20  T14
# Acinar cell_Ductal cell type 2         0.010623  0.005887  0.000000  0.0
# Acinar cell_Endothelial cell           0.012045  0.008155  0.000000  0.0
# Acinar cell_Stellate cell              0.005348  0.001810  0.000000  0.0
# Acinar cell_Fibroblast cell            0.009957  0.005515  0.000000  0.0
# Acinar cell_Ductal cell type 1         0.010349  0.005083  0.000000  0.0
# ...                                         ...       ...       ...  ...
# Ductal cell type 1_Macrophage cell     0.012174  0.012384  0.020447  0.0
# Ductal cell type 1_Stellate cell       0.008616  0.007708  0.023156  0.0
# Ductal cell type 1_T cell              0.007788  0.012468  0.016994  0.0
# Ductal cell type 1_Fibroblast cell     0.014659  0.014204  0.000000  0.0
# Ductal cell type 1_Ductal cell type 1  0.017691  0.014759  0.025188  0.0
#
# [80 rows x 28 columns]

# %% [markdown]
# #### 6. Building the Cost Matrix

# %% [markdown]
# Here we can compute all possible default options of cost matrix, for the details please read our manuscript. For instance we gonna focus in the CTD cost matrix by now.
#
# ```{python}
# AaccPDAC.compute_cost_all() ## Run all the possible cost matrices
# ```

# %%
AaccPDAC.compute_cost_all()
# Out:
# CTD
# /home/james/.local/lib/python3.10/site-packages/accordion/distances.py:13: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   A = nx.adjacency_matrix(G,weight=weight).todense()
# ('distance', 'correlation')
# glasso
# /home/james/.local/lib/python3.10/site-packages/numpy/core/_methods.py:232: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)

# %%
AaccPDAC.compute_wassestein('correlation')
AaccPDAC.compute_wassestein('glasso')
AaccPDAC.compute_wassestein('CTD')
# Out:
# 100%|███████████████████████████████████████████| 28/28 [00:00<00:00, 90.64it/s]
# 100%|███████████████████████████████████████████| 28/28 [00:00<00:00, 92.36it/s]
# 100%|███████████████████████████████████████████| 28/28 [00:00<00:00, 89.00it/s]

# %% [markdown]
# #### 6. Clustering the wasserstein distance matrix

# %%
twoclsm = KMeans(n_clusters=2)
aux = dm.diffusion_map.DiffusionMap.from_sklearn(metric='precomputed',
                                                 n_evecs = 2, 
                                                 epsilon =1, 
                                                 alpha = 0.5, 
                                                 k=64)
aux = aux.fit_transform(AaccPDAC.wdist['CTD'])

# %%
_,ax1 = plt.subplots(1,2,figsize=(10,4))
ax1 = ax1.ravel()
sns.scatterplot(x=aux[:,0],y=aux[:,1],hue=twoclsm.fit_predict(AaccPDAC.wdist['CTD']),ax=ax1[0]) 
ax1[0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=5)
ax1[0].set_title('Kmeans in the $W$-space')
ax1[0].set_xlabel('DM1')
ax1[0].set_ylabel('DM2')
sns.scatterplot(x=aux[:,0],y=aux[:,1],hue=pdata_metadata.loc[AaccPDAC.Cs['PCA'].index,'label1'],ax=ax1[1])
ax1[1].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=5)
ax1[1].set_title('Original Labels')
ax1[1].set_xlabel('DM1')
ax1[1].set_ylabel('DM2')
# Out:
# Text(0, 0.5, 'DM2')

# %%
threeclsm = KMeans(n_clusters=3)
threeclsm = threeclsm.fit_predict(AaccPDAC.wdist['CTD'])

# %%
_,ax1 = plt.subplots(1,2,figsize=(10,4))
ax1 = ax1.ravel()
sns.scatterplot(x=aux[:,0],y=aux[:,1],hue=threeclsm,ax=ax1[0]) 
ax1[0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=5)
ax1[0].set_title('Kmeans in the $W$-space')
ax1[0].set_xlabel('DM1')
ax1[0].set_ylabel('DM2')

sns.scatterplot(x=aux[:,0],y=aux[:,1],hue=pdata_metadata.loc[AaccPDAC.Cs['PCA'].index,'label1'],ax=ax1[1])
ax1[1].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=5)
ax1[1].set_title('Original Labels')
ax1[1].set_xlabel('DM1')
ax1[1].set_ylabel('DM2')
# Out:
# Text(0, 0.5, 'DM2')

# %% [markdown]
# #### 7. Explaining our clusters

# %%
pdata_metadata.loc[AaccPDAC.p.columns,'cls'] = threeclsm

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_regression
import numpy as np
regr = RandomForestClassifier(max_depth=2, random_state=0)
edist = AaccPDAC.p.T
regr.fit(edist, threeclsm)
sel =AaccPDAC.p.iloc[np.argsort(regr.feature_importances_)[::-1][0:15],]
plt.figure()
sns.clustermap(sel.T,cmap='RdYlBu_r',row_cluster=True,z_score=1)
plt.show()

# %% [markdown]
# ####  8. Features per Samples

# %%
fig2,ax2 = plt.subplots(3,5,figsize=(30,12),dpi=300)
ax2 = ax2.ravel()
it=regr.feature_names_in_[np.argsort(regr.feature_importances_)[::-1][0:15]]
for idi, i in enumerate(it):
    sns.scatterplot(x=aux[:,0],
                    y=aux[:,1],
                    hue=edist.T.loc[i,],
                    ax=ax2[idi],legend=False,palette='RdYlBu_r',s=100)
    ax2[idi].set_title(f"{i}",fontdict={"fontsize":20})

# %%
import numpy.linalg as lg

# %%
wscores = AaccPDAC.p @ lg.svd(AaccPDAC.wdist['CTD'])[1].reshape(len(lg.svd(AaccPDAC.wdist['CTD'])[1]),1)

# %%
fig2,ax2 = plt.subplots(3,5,figsize=(30,12),dpi=300)
ax2 = ax2.ravel()
it=wscores.sort_values(0,ascending=False).iloc[0:15].index.tolist()
for idi, i in enumerate(it):
    sns.scatterplot(x=aux[:,0],
                    y=aux[:,1],
                    hue=edist.T.loc[i,],
                    ax=ax2[idi],legend=False,palette='RdYlBu_r',s=100)
    ax2[idi].set_title(f"{i}",fontdict={"fontsize":20})

# %%
wscores.columns=['sigma_scaling']

# %%
wscores.loc[regr.feature_names_in_,'rf-feature']= regr.feature_importances_

# %%
wscores.corr(method='spearman')
# Out:
#                sigma_scaling  rf-feature
# sigma_scaling       1.000000    0.232948
# rf-feature          0.232948    1.000000

# %%
sns.scatterplot(x='sigma_scaling',y='rf-feature',data=wscores)
for i in range(wscores.shape[0]):
    plt.text(x=wscores['sigma_scaling'][i],
             y=wscores['rf-feature'][i],s=list(wscores.index)[i],size=10)

# %%
tmp=nx.adjacency_matrix(AaccPDAC.expgraph).todense()
# Out:
# /tmp/ipykernel_517682/3172121730.py:1: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   tmp=nx.adjacency_matrix(AaccPDAC.expgraph).todense()

# %%
from scipy.linalg import norm
for i in range(tmp.shape[0]):
    tmp[i,:]=tmp[i,:]/norm(tmp[i,:],ord=1)

# %%
#tmp = lg.svd(AaccPDAC.wdist['CTD'])[1] * np.eye(len(lg.svd(AaccPDAC.wdist['CTD'])[1]))
tmp = AaccPDAC.wdist['CTD']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [41], line 2
#       1 #tmp = lg.svd(AaccPDAC.wdist['CTD'])[1] * np.eye(len(lg.svd(AaccPDAC.wdist['CTD'])[1]))
# ----> 2 tmp = AaccPDAC.wdist['dhalf']
#
# KeyError: 'dhalf'

# %%
it=regr.feature_names_in_[np.argsort(regr.feature_importances_)[::-1][0:15]]
clr=['r' if i=="PDAC" else 'g' for i in pdata_metadata.loc[AaccPDAC.wdist['CTD'].columns,'label1']]

# %%
for idi, i in enumerate(it):
    pini = AaccPDAC.p.loc[i,:]
    avgsis = {}
    for it in range(10):
        pstar = tmp @ pini
        avgsis[it]=pstar
        pini=pstar
    tmpe1 = pd.DataFrame.from_dict(avgsis)
    tmpe1.index=AaccPDAC.wdist['CTD'].columns
    tmpe1.T.plot(legend=None,title=i,color=clr)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In [40], line 5
#       3 avgsis = {}
#       4 for it in range(10):
# ----> 5     pstar = tmp @ pini
#       6     avgsis[it]=pstar
#       7     pini=pstar
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:2032, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2029 def __array_ufunc__(
#    2030     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2031 ):
# -> 2032     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:253, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     250     return result
#     252 # for binary ops, use our custom dunder methods
# --> 253 result = maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
#     254 if result is not NotImplemented:
#     255     return result
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/ops_dispatch.pyx:91, in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:2786, in Series.__rmatmul__(self, other)
#    2782 def __rmatmul__(self, other):
#    2783     """
#    2784     Matrix multiplication using binary `@` operator in Python>=3.5.
#    2785     """
# -> 2786     return self.dot(np.transpose(other))
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:2761, in Series.dot(self, other)
#    2759     rvals = np.asarray(other)
#    2760     if lvals.shape[0] != rvals.shape[0]:
# -> 2761         raise Exception(
#    2762             f"Dot product shape mismatch, {lvals.shape} vs {rvals.shape}"
#    2763         )
#    2765 if isinstance(other, ABCDataFrame):
#    2766     return self._constructor(
#    2767         np.dot(lvals, rvals), index=other.columns
#    2768     ).__finalize__(self, method="dot")
#
# Exception: Dot product shape mismatch, (28,) vs (80, 80)
